# %%
print("Kalkulator Luas Lingkaran")
# Out:
# Kalkulator Luas Lingkaran

# %%
radius = float(input("Masukkan jari-jari lingkaran (tidak usah pakai cm): "))
# Out:
# Masukkan jari-jari lingkaran (tidak usah pakai cm): 7

# %%
area = 22/7 * radius * radius

# %%
print("Luas lingkaran dengan jari-jari" + str(radius) + " cm adalah " + str(area) " cm\u00b2") #saya nggak tau ini salah dimana
# Out:
#   Input In [29]
#     print("Luas lingkaran dengan jari-jari" + str(radius) + " cm adalah " + str(area) " cm\u00b2")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
