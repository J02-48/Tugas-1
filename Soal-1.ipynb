# %%
nama = input("Masukkan nama anda: ")
# Out:
# Masukkan nama anda: Jojo

# %%
Umur = int(input("Masukkan umur anda: "))
# Out:
# Masukkan umur anda: 14

# %%
tinggi = float(input("Masukkan tinggi badan anda: "))
# Out:
# Masukkan tinggi badan anda: 163

# %%
konklusi = "Nama saya {}, umur saya {} tahun dan tinggi saya {} cm.".format(nama, Umur, tinggi)

# %%
print(konklusi)
# Out:
# Nama saya Jojo, umur saya 14 tahun dan tinggi saya 163.0 cm.
